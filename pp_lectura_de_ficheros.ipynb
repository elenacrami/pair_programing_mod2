# %% [markdown]
# # Ejercicio de Lectura de ficheros
#
# Hacer las importaciones necesarias para abrir un archivo de tipo "csv" en Pand
# as.
#
# Abrir el archivo, creando un Dataframe. Aseguraros de que no incluye la columna "Unnamed: 0".
#
# Guardar el Dataframe en formato Excel y después crear un Dataframe con el Excel. ¿EL Dataframe es similar al que teníais antes?
#
# Crear una carpeta llamada Files y guardar el mismo archivo en esa carpeta en formato csv .
#
# Copia el archivo personal.json en la carpeta Files.
#
# Abre el json y haz las modificaciones necesarias para poder abrirlo correctamente en Pandas.
#
# Guardar el json modifiado y abrirlo en Pandas para que tenga formato de tabla.

# %%
import pandas as pd
import json 

df = pd.read_csv("videogames.csv", index_col = 0)  # Abrimos el .csv desde pandas. Ahora es un dataframe
df.head()
# Out:
#                          name  \
# 0                  Spider-Man
# 1      Red Dead Redemption II
# 2          Grand Theft Auto V
# 3                  God of War
# 4  Uncharted 4: A Thief's End
#
#                                                  url    year certificate  \
# 0  https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1  https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2  https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3  https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# 4  https://www.imdb.com/title/tt3334704/?ref_=adv...  2016.0           T
#
#    rating   votes                                               plot  Action  \
# 0     9.2  20,759  When a new villain threatens New York City, Pe...    True
# 1     9.7  35,703  Amidst the decline of the Wild West at the tur...    True
# 2     9.5  59,986  Three very different criminals team up for a s...    True
# ...

# %% [markdown]
# Guardar el Dataframe en formato Excel y después crear un Dataframe con el Excel. ¿EL Dataframe es similar al que teníais antes?

# %%
df.to_excel("videogames.xlsx")

# %%
df_excel = pd.read_excel("videogames.xlsx", index_col = 0)
df_excel.head()
# Out:
#                          name  \
# 0                  Spider-Man
# 1      Red Dead Redemption II
# 2          Grand Theft Auto V
# 3                  God of War
# 4  Uncharted 4: A Thief's End
#
#                                                  url    year certificate  \
# 0  https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1  https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2  https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3  https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# 4  https://www.imdb.com/title/tt3334704/?ref_=adv...  2016.0           T
#
#    rating   votes                                               plot  Action  \
# 0     9.2  20,759  When a new villain threatens New York City, Pe...    True
# 1     9.7  35,703  Amidst the decline of the Wild West at the tur...    True
# 2     9.5  59,986  Three very different criminals team up for a s...    True
# ...

# %% [markdown]
# Crear una carpeta llamada Files y guardar el mismo archivo en esa carpeta en formato csv.

# %%
df_excel.to_csv("Files/videogames.csv") # Convertimos el archivo y le pasamos la ruta donde almacenarlo.

# %% [markdown]
# Copia el archivo personal.json en la carpeta Files.

# %%
# Probamos a hacerlo vía pandas.

# la ruta. Nosotras estamos en la carpeta "en clase". Queremos 1) subir a carpeta pair programming. 2) 

df_personal = pd.read_json("../../teoria/personal.json")  

df_personal.to_json("Files/personal.json")

# %% [markdown]
# Abre el json y haz las modificaciones necesarias para poder abrirlo correctamente en Pandas.
#
# Guardar el json modificado y abrirlo en Pandas para que tenga formato de tabla.

# %%
# Esto funciona, pero no es demasiado legible. ¿Cómo le damos formato para que las claves sean columnas?

"""

            Nombre  Edad    Experiencia     Nivel   Salario     Mascota
Worker 0
Worker 1
Worker 2
Worker 3 
"""

# %%
# Probemos a abrir json con Python. 

with open("Files/personal.json", "r") as fichero: 
    personal = json.load(fichero) # Almacenamos el fichero ersonal.json en la variable personal


print(json.dumps(personal, indent=4))
# Out:
# {
#     "workers": {
#         "0": {
#             "nombre": "Ana",
#             "edad": 34,
#             "experiencia": 5,
#             "nivel": "Senior",
#             "salario": 50000,
#             "mascota": "gatos"
#         },
#         "1": {
#             "nombre": "Eva",
#             "edad": 37,
#             "experiencia": 2,
#             "nivel": "Mid",
#             "salario": 35000
#         },
#         "2": {
#             "nombre": "Marta",
#             "edad": 27,
#             "experiencia": 1,
#             "nivel": "Junior",
#             "salario": 25000
#         },
#         "3": {
#             "nombre": "Paula",
#             "edad": 30,
#             "experiencia": 3,
#             "nivel": "Mid",
#             "salario": 35000
#         }
#     }
# }

# %%
diccionario_nuevo = personal["workers"]
print(diccionario_nuevo)
print(len(diccionario_nuevo))

tabla1 = pd.DataFrame(diccionario_nuevo)
print(tabla1)
# Out:
# {'0': {'nombre': 'Ana', 'edad': 34, 'experiencia': 5, 'nivel': 'Senior', 'salario': 50000, 'mascota': 'gatos'}, '1': {'nombre': 'Eva', 'edad': 37, 'experiencia': 2, 'nivel': 'Mid', 'salario': 35000}, '2': {'nombre': 'Marta', 'edad': 27, 'experiencia': 1, 'nivel': 'Junior', 'salario': 25000}, '3': {'nombre': 'Paula', 'edad': 30, 'experiencia': 3, 'nivel': 'Mid', 'salario': 35000}}
# 4
#                   0      1       2      3
# nombre          Ana    Eva   Marta  Paula
# edad             34     37      27     30
# experiencia       5      2       1      3
# nivel        Senior    Mid  Junior    Mid
# salario       50000  35000   25000  35000
# mascota       gatos    NaN     NaN    NaN

# %%
diccionario_nuevo2 = personal["workers"]["0"]
print(diccionario_nuevo2)
print(len(diccionario_nuevo2))

tabla2 = pd.DataFrame(diccionario_nuevo2)
print(tabla2)
# Out:
# {'nombre': 'Ana', 'edad': 34, 'experiencia': 5, 'nivel': 'Senior', 'salario': 50000, 'mascota': 'gatos'}
# 6
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[77], line 5
#       2 print(diccionario_nuevo2)
#       3 print(len(diccionario_nuevo2))
# ----> 5 tabla2 = pd.DataFrame(diccionario_nuevo2)
#       6 print(tabla2)
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
# ...

# %% [markdown]
# # Lista de deseos:

# %%
# chuleta carla

df_json.head()

df_json.set_index(df_json.columns[3], inplace=True)
